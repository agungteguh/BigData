# %%
# Konfigurasi Spark
import os
import sys

# 1. Mengeset variabel yang menyimpan lokasi di mana Spark diinstal
spark_path = "D:/spark"

# 2. Menentukan environment variable SPARK_HOME
os.environ['SPARK_HOME'] = spark_path

# 3. Simpan lokasi winutils.exe sebagai environment variable HADOOP_HOME
os.environ['HADOOP_HOME'] = spark_path

# 4. Lokasi Python yang dijalankan --> punya Anaconda
#    Apabila Python yang diinstall hanya Anaconda, maka tidak perlu menjalankan baris ini.
os.environ['PYSPARK_PYTHON'] = sys.executable

# 5. Konfigurasi path library PySpark
sys.path.append(spark_path + "/bin")
sys.path.append(spark_path + "/python")
sys.path.append(spark_path + "/python/pyspark/")
sys.path.append(spark_path + "/python/lib")
sys.path.append(spark_path + "/python/lib/pyspark.zip")
sys.path.append(spark_path + "/python/lib/py4j-0.10.4-src.zip")

# 6. Import library Spark
#    Dua library yang WAJIB di-import adalah **SparkContext** dan **SparkConf**.
from pyspark import SparkContext
from pyspark import SparkConf

# Setting konfigurasi (opsional)
conf = SparkConf()
conf.set("spark.executor.memory", "2g")
conf.set("spark.cores.max", "4")

sc = SparkContext("local", conf=conf)
#    Apabila berhasil, maka ketika sc di-print akan mengeluarkan nilai <pyspark.context.SparkContext object>
print sc
# Out:
# <pyspark.context.SparkContext object at 0x000000000594A0F0>

# %%
# The usual preamble
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)
plt.rcParams['font.family'] = 'sans-serif'

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# C:\Users\agungteguh\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
request = pd.read_csv('vgsales.csv',na_values='')
request.count()
# Out:
# Rank            16598
# Name            16598
# Platform        16598
# Year            16327
# Genre           16598
# Publisher       16540
# NA_Sales        16598
# EU_Sales        16598
# JP_Sales        16598
# Other_Sales     16598
# Global_Sales    16598
# dtype: int64

# %%
req = (request.drop('NA_Sales', axis=1)
         .join(request['NA_Sales'].apply(pd.to_numeric, errors='coerce')))

req2 = (req.drop('EU_Sales', axis=1)
         .join(req['EU_Sales'].apply(pd.to_numeric, errors='coerce')))

req3 = (req2.drop('JP_Sales', axis=1)
         .join(req['JP_Sales'].apply(pd.to_numeric, errors='coerce')))

req4 = (req3.drop('Other_Sales', axis=1)
         .join(req['Other_Sales'].apply(pd.to_numeric, errors='coerce')))

# %%
reqcopy = req4[['NA_Sales', 'EU_Sales','JP_Sales','Other_Sales']].copy()
reqany = reqcopy.dropna(how='any')

# %%
from numpy import array
from math import sqrt
from pyspark.mllib.clustering import KMeans, KMeansModel
from pyspark.sql import SQLContext
sqlcontext = SQLContext(sc)
datacleansing = sqlcontext.createDataFrame(reqany)
datacleansing.take(50)
# Out:
# [Row(NA_Sales=41.49, EU_Sales=29.02, JP_Sales=3.77, Other_Sales=8.46),
#  Row(NA_Sales=29.08, EU_Sales=3.58, JP_Sales=6.81, Other_Sales=0.77),
#  Row(NA_Sales=15.85, EU_Sales=12.88, JP_Sales=3.79, Other_Sales=3.31),
#  Row(NA_Sales=15.75, EU_Sales=11.01, JP_Sales=3.28, Other_Sales=2.96),
#  Row(NA_Sales=11.27, EU_Sales=8.89, JP_Sales=10.22, Other_Sales=1.0),
#  Row(NA_Sales=23.2, EU_Sales=2.26, JP_Sales=4.22, Other_Sales=0.58),
#  Row(NA_Sales=11.38, EU_Sales=9.23, JP_Sales=6.5, Other_Sales=2.9),
#  Row(NA_Sales=14.03, EU_Sales=9.2, JP_Sales=2.93, Other_Sales=2.85),
#  Row(NA_Sales=14.59, EU_Sales=7.06, JP_Sales=4.7, Other_Sales=2.26),
#  Row(NA_Sales=26.93, EU_Sales=0.63, JP_Sales=0.28, Other_Sales=0.47),
#  Row(NA_Sales=9.07, EU_Sales=11.0, JP_Sales=1.93, Other_Sales=2.75),
#  Row(NA_Sales=9.81, EU_Sales=7.57, JP_Sales=4.13, Other_Sales=1.92),
#  Row(NA_Sales=9.0, EU_Sales=6.18, JP_Sales=7.2, Other_Sales=0.71),
#  Row(NA_Sales=8.94, EU_Sales=8.03, JP_Sales=3.6, Other_Sales=2.15),
#  Row(NA_Sales=9.09, EU_Sales=8.59, JP_Sales=2.53, Other_Sales=1.79),
#  Row(NA_Sales=14.97, EU_Sales=4.94, JP_Sales=0.24, Other_Sales=1.67),
#  Row(NA_Sales=7.01, EU_Sales=9.27, JP_Sales=0.97, Other_Sales=4.14),
#  Row(NA_Sales=9.43, EU_Sales=0.4, JP_Sales=0.41, Other_Sales=10.57),
#  Row(NA_Sales=12.78, EU_Sales=3.75, JP_Sales=3.54, Other_Sales=0.55),
#  Row(NA_Sales=4.75, EU_Sales=9.26, JP_Sales=4.16, Other_Sales=2.05),
#  Row(NA_Sales=6.42, EU_Sales=4.52, JP_Sales=6.04, Other_Sales=1.37),
#  Row(NA_Sales=10.83, EU_Sales=2.71, JP_Sales=4.18, Other_Sales=0.42),
#  Row(NA_Sales=9.54, EU_Sales=3.44, JP_Sales=3.84, Other_Sales=0.46),
#  Row(NA_Sales=9.63, EU_Sales=5.31, JP_Sales=0.06, Other_Sales=1.38),
#  Row(NA_Sales=8.41, EU_Sales=5.49, JP_Sales=0.47, Other_Sales=1.78),
#  Row(NA_Sales=6.06, EU_Sales=3.9, JP_Sales=5.38, Other_Sales=0.5),
#  Row(NA_Sales=5.57, EU_Sales=3.28, JP_Sales=5.65, Other_Sales=0.82),
#  Row(NA_Sales=3.44, EU_Sales=5.36, JP_Sales=5.32, Other_Sales=1.18),
#  Row(NA_Sales=6.85, EU_Sales=5.09, JP_Sales=1.87, Other_Sales=1.16),
#  Row(NA_Sales=9.03, EU_Sales=4.28, JP_Sales=0.13, Other_Sales=1.32),
#  Row(NA_Sales=5.89, EU_Sales=5.04, JP_Sales=3.12, Other_Sales=0.59),
#  Row(NA_Sales=9.67, EU_Sales=3.73, JP_Sales=0.11, Other_Sales=1.13),
#  Row(NA_Sales=5.17, EU_Sales=4.05, JP_Sales=4.34, Other_Sales=0.79),
#  Row(NA_Sales=5.77, EU_Sales=5.81, JP_Sales=0.35, Other_Sales=2.31),
#  Row(NA_Sales=4.99, EU_Sales=5.88, JP_Sales=0.65, Other_Sales=2.52),
#  Row(NA_Sales=8.25, EU_Sales=4.3, JP_Sales=0.07, Other_Sales=1.12),
#  Row(NA_Sales=8.52, EU_Sales=3.63, JP_Sales=0.08, Other_Sales=1.29),
#  Row(NA_Sales=5.54, EU_Sales=5.82, JP_Sales=0.49, Other_Sales=1.62),
#  Row(NA_Sales=6.99, EU_Sales=4.51, JP_Sales=0.3, Other_Sales=1.3),
#  Row(NA_Sales=6.75, EU_Sales=2.61, JP_Sales=2.66, Other_Sales=1.02),
#  Row(NA_Sales=5.98, EU_Sales=4.44, JP_Sales=0.48, Other_Sales=1.83),
#  Row(NA_Sales=2.55, EU_Sales=3.52, JP_Sales=5.33, Other_Sales=0.88),
#  Row(NA_Sales=4.74, EU_Sales=3.91, JP_Sales=2.67, Other_Sales=0.89),
#  Row(NA_Sales=7.97, EU_Sales=2.83, JP_Sales=0.13, Other_Sales=1.21),
#  Row(NA_Sales=3.8, EU_Sales=5.81, JP_Sales=0.36, Other_Sales=2.02),
#  Row(NA_Sales=4.4, EU_Sales=2.77, JP_Sales=3.96, Other_Sales=0.77),
#  Row(NA_Sales=6.91, EU_Sales=2.85, JP_Sales=1.91, Other_Sales=0.23),
#  Row(NA_Sales=3.01, EU_Sales=0.01, JP_Sales=1.1, Other_Sales=7.53),
#  Row(NA_Sales=6.16, EU_Sales=3.4, JP_Sales=1.2, Other_Sales=0.76),
#  Row(NA_Sales=4.23, EU_Sales=3.37, JP_Sales=3.08, Other_Sales=0.65)]

# %%
rdd = datacleansing.rdd
result = rdd.map(lambda line: array([x for x in line]))

# %%
result.collect()
# Out:
# [array([ 41.49,  29.02,   3.77,   8.46]),
#  array([ 29.08,   3.58,   6.81,   0.77]),
#  array([ 15.85,  12.88,   3.79,   3.31]),
#  array([ 15.75,  11.01,   3.28,   2.96]),
#  array([ 11.27,   8.89,  10.22,   1.  ]),
#  array([ 23.2 ,   2.26,   4.22,   0.58]),
#  array([ 11.38,   9.23,   6.5 ,   2.9 ]),
#  array([ 14.03,   9.2 ,   2.93,   2.85]),
#  array([ 14.59,   7.06,   4.7 ,   2.26]),
#  array([ 26.93,   0.63,   0.28,   0.47]),
#  array([  9.07,  11.  ,   1.93,   2.75]),
#  array([ 9.81,  7.57,  4.13,  1.92]),
#  array([ 9.  ,  6.18,  7.2 ,  0.71]),
#  array([ 8.94,  8.03,  3.6 ,  2.15]),
#  array([ 9.09,  8.59,  2.53,  1.79]),
#  array([ 14.97,   4.94,   0.24,   1.67]),
#  array([ 7.01,  9.27,  0.97,  4.14]),
#  array([  9.43,   0.4 ,   0.41,  10.57]),
#  array([ 12.78,   3.75,   3.54,   0.55]),
#  array([ 4.75,  9.26,  4.16,  2.05]),
#  array([ 6.42,  4.52,  6.04,  1.37]),
#  array([ 10.83,   2.71,   4.18,   0.42]),
#  array([ 9.54,  3.44,  3.84,  0.46]),
#  array([ 9.63,  5.31,  0.06,  1.38]),
#  array([ 8.41,  5.49,  0.47,  1.78]),
#  array([ 6.06,  3.9 ,  5.38,  0.5 ]),
#  array([ 5.57,  3.28,  5.65,  0.82]),
#  array([ 3.44,  5.36,  5.32,  1.18]),
#  array([ 6.85,  5.09,  1.87,  1.16]),
#  array([ 9.03,  4.28,  0.13,  1.32]),
#  array([ 5.89,  5.04,  3.12,  0.59]),
#  array([ 9.67,  3.73,  0.11,  1.13]),
#  array([ 5.17,  4.05,  4.34,  0.79]),
#  array([ 5.77,  5.81,  0.35,  2.31]),
#  array([ 4.99,  5.88,  0.65,  2.52]),
#  array([ 8.25,  4.3 ,  0.07,  1.12]),
#  array([ 8.52,  3.63,  0.08,  1.29]),
#  array([ 5.54,  5.82,  0.49,  1.62]),
#  array([ 6.99,  4.51,  0.3 ,  1.3 ]),
#  array([ 6.75,  2.61,  2.66,  1.02]),
#  array([ 5.98,  4.44,  0.48,  1.83]),
#  array([ 2.55,  3.52,  5.33,  0.88]),
#  array([ 4.74,  3.91,  2.67,  0.89]),
#  array([ 7.97,  2.83,  0.13,  1.21]),
#  array([ 3.8 ,  5.81,  0.36,  2.02]),
#  array([ 4.4 ,  2.77,  3.96,  0.77]),
#  array([ 6.91,  2.85,  1.91,  0.23]),
#  array([ 3.01,  0.01,  1.1 ,  7.53]),
#  array([ 6.16,  3.4 ,  1.2 ,  0.76]),
#  array([ 4.23,  3.37,  3.08,  0.65]),
#  array([ 6.16,  2.04,  2.69,  0.29]),
#  array([ 6.76,  3.1 ,  0.14,  1.03]),
#  array([ 4.02,  3.87,  2.54,  0.52]),
#  array([ 4.89,  2.99,  2.13,  0.78]),
#  array([ 2.96,  4.88,  0.81,  2.12]),
#  array([ 4.99,  3.69,  0.38,  1.63]),
#  array([ 4.76,  3.76,  0.44,  1.62]),
#  array([ 5.99,  2.15,  2.12,  0.29]),
#  array([ 4.34,  2.65,  3.15,  0.35]),
#  array([ 5.08,  3.11,  1.25,  0.98]),
#  array([ 6.05,  3.15,  0.  ,  1.07]),
#  array([ 6.72,  2.63,  0.04,  0.82]),
#  array([ 7.03,  1.98,  0.08,  0.78]),
#  array([ 5.55,  1.94,  2.23,  0.15]),
#  array([ 3.66,  3.07,  2.47,  0.63]),
#  array([ 6.63,  2.36,  0.04,  0.73]),
#  array([ 3.01,  2.47,  3.28,  0.96]),
#  array([ 4.09,  3.73,  0.38,  1.38]),
#  array([ 5.84,  2.89,  0.01,  0.78]),
#  array([ 3.88,  3.42,  1.69,  0.5 ]),
#  array([ 5.91,  2.38,  0.13,  0.9 ]),
#  array([ 4.36,  1.71,  3.  ,  0.23]),
#  array([ 5.58,  2.83,  0.02,  0.77]),
#  array([ 2.01,  2.32,  4.36,  0.41]),
#  array([ 4.46,  1.88,  1.98,  0.7 ]),
#  array([ 5.03,  2.86,  0.1 ,  0.85]),
#  array([ 3.54,  1.24,  3.81,  0.18]),
#  array([ 1.11,  6.06,  0.06,  1.26]),
#  array([ 1.79,  3.53,  2.49,  0.68]),
#  array([ 6.82,  1.53,  0.05,  0.08]),
#  array([ 3.81,  2.3 ,  1.58,  0.73]),
#  array([ 2.91,  1.86,  3.14,  0.43]),
#  array([ 1.06,  5.05,  0.13,  2.01]),
#  array([ 0.98,  6.42,  0.  ,  0.71]),
#  array([ 5.8 ,  2.01,  0.13,  0.15]),
#  array([ 2.58,  3.9 ,  0.66,  0.91]),
#  array([ 2.91,  2.07,  2.73,  0.33]),
#  array([ 2.28,  1.72,  3.63,  0.23]),
#  array([ 2.82,  1.78,  2.69,  0.55]),
#  array([ 7.28,  0.45,  0.  ,  0.08]),
#  array([ 2.9 ,  2.83,  0.24,  1.75]),
#  array([ 3.66,  2.42,  0.98,  0.64]),
#  array([ 2.93,  3.29,  0.22,  1.23]),
#  array([ 2.8 ,  3.3 ,  0.14,  1.37]),
#  array([ 4.1 ,  1.89,  1.45,  0.16]),
#  array([ 3.78,  2.17,  1.31,  0.31]),
#  array([ 5.39,  1.18,  0.7 ,  0.19]),
#  array([ 3.24,  1.35,  2.42,  0.43]),
#  array([ 4.79,  1.9 ,  0.  ,  0.69]),
#  array([ 4.46,  2.13,  0.06,  0.69]),
#  array([ 3.83,  2.19,  0.6 ,  0.7 ]),
#  array([ 4.52,  2.09,  0.01,  0.67]),
#  array([ 3.51,  3.03,  0.  ,  0.73]),
#  array([ 2.85,  2.93,  0.35,  1.1 ]),
#  array([ 3.27,  2.83,  0.08,  1.02]),
#  array([ 3.27,  2.22,  1.4 ,  0.29]),
#  array([ 3.68,  1.75,  1.42,  0.28]),
#  array([ 4.41,  1.04,  1.39,  0.22]),
#  array([ 3.13,  2.07,  1.27,  0.49]),
#  array([ 2.47,  3.15,  0.24,  1.1 ]),
#  array([ 4.12,  1.77,  0.87,  0.19]),
#  array([ 4.14,  2.21,  0.  ,  0.56]),
#  array([ 0.78,  4.32,  0.07,  1.73]),
#  array([ 2.71,  3.02,  0.08,  1.09]),
#  array([ 2.93,  2.75,  0.17,  0.99]),
#  array([ 2.77,  2.8 ,  0.19,  1.06]),
#  array([ 3.23,  2.35,  0.94,  0.3 ]),
#  array([ 3.5 ,  2.64,  0.  ,  0.67]),
#  array([ 4.15,  1.92,  0.06,  0.64]),
#  array([ 3.27,  2.25,  0.21,  1.  ]),
#  array([ 3.1 ,  2.3 ,  0.28,  1.04]),
#  array([ 0.84,  4.32,  0.11,  1.42]),
#  array([ 1.67,  2.78,  1.6 ,  0.62]),
#  array([ 2.79,  2.61,  0.17,  1.03]),
#  array([ 0.79,  4.29,  0.05,  1.47]),
#  array([ 3.25,  1.84,  1.03,  0.47]),
#  array([ 2.55,  2.71,  0.25,  1.05]),
#  array([ 3.74,  0.93,  1.69,  0.14]),
#  array([ 2.64,  2.56,  0.16,  1.14]),
#  array([ 4.98,  1.3 ,  0.08,  0.07]),
#  array([ 2.57,  1.58,  2.06,  0.21]),
#  array([ 3.64,  1.2 ,  1.49,  0.07]),
#  array([ 2.55,  1.56,  1.29,  0.99]),
#  array([ 4.34,  1.35,  0.06,  0.61]),
#  array([ 3.7 ,  1.97,  0.09,  0.57]),
#  array([ 4.01,  1.26,  0.87,  0.17]),
#  array([ 2.47,  0.83,  2.87,  0.12]),
#  array([ 0.07,  6.21,  0.  ,  0.  ]),
#  array([ 3.11,  2.8 ,  0.02,  0.33]),
#  array([ 3.92,  1.78,  0.03,  0.51]),
#  array([ 4.05,  1.62,  0.07,  0.49]),
#  array([ 3.54,  1.9 ,  0.07,  0.6 ]),
#  array([ 2.45,  2.01,  0.87,  0.72]),
#  array([ 4.47,  1.2 ,  0.16,  0.19]),
#  array([ 2.63,  1.74,  0.83,  0.83]),
#  array([ 3.18,  1.83,  0.78,  0.24]),
#  array([ 2.41,  2.28,  0.28,  1.01]),
#  array([ 1.88,  0.  ,  2.33,  1.74]),
#  array([ 2.8 ,  2.05,  0.17,  0.9 ]),
#  array([ 0.66,  0.69,  4.35,  0.15]),
#  array([ 3.66,  1.63,  0.  ,  0.53]),
#  array([ 1.88,  1.47,  2.02,  0.45]),
#  array([ 2.26,  1.89,  1.36,  0.23]),
#  array([ 3.13,  1.94,  0.07,  0.58]),
#  array([ 2.49,  2.05,  0.16,  0.96]),
#  array([ 2.97,  0.69,  1.81,  0.11]),
#  array([ 2.54,  1.95,  0.21,  0.87]),
#  array([ 2.95,  0.6 ,  1.97,  0.04]),
#  array([ 3.28,  1.65,  0.07,  0.55]),
#  array([ 2.7 ,  1.91,  0.11,  0.8 ]),
#  array([ 2.99,  1.92,  0.1 ,  0.51]),
#  array([ 0.47,  0.57,  4.13,  0.34]),
#  array([ 3.14,  1.24,  0.91,  0.2 ]),
#  array([ 2.62,  1.64,  0.99,  0.23]),
#  array([ 3.21,  1.11,  0.95,  0.2 ]),
#  array([ 3.18,  1.24,  0.94,  0.09]),
#  array([ 2.72,  1.87,  0.  ,  0.84]),
#  array([ 2.07,  2.29,  0.24,  0.82]),
#  array([ 1.97,  2.51,  0.  ,  0.94]),
#  array([ 1.74,  1.24,  1.87,  0.52]),
#  array([ 2.18,  0.96,  2.  ,  0.2 ]),
#  array([ 3.02,  1.12,  1.01,  0.16]),
#  array([ 3.13,  1.71,  0.03,  0.44]),
#  array([ 1.62,  0.77,  2.78,  0.14]),
#  array([ 1.92,  1.08,  2.11,  0.17]),
#  array([ 3.33,  0.79,  1.09,  0.06]),
#  array([ 3.1 ,  1.56,  0.08,  0.51]),
#  array([ 1.22,  2.48,  1.03,  0.52]),
#  array([ 2.3 ,  2.46,  0.2 ,  0.28]),
#  array([ 4.26,  0.26,  0.01,  0.71]),
#  array([ 0.65,  0.75,  3.61,  0.2 ]),
#  array([ 2.43,  2.15,  0.  ,  0.62]),
#  array([ 2.93,  1.25,  0.83,  0.2 ]),
#  array([ 2.32,  1.3 ,  1.27,  0.31]),
#  array([ 2.49,  0.98,  1.57,  0.15]),
#  array([ 1.08,  3.48,  0.03,  0.58]),
#  array([ 1.9 ,  1.83,  0.95,  0.49]),
#  array([ 2.1 ,  0.74,  2.2 ,  0.11]),
#  array([ 0.96,  2.02,  1.89,  0.28]),
#  array([ 1.64,  2.48,  0.44,  0.58]),
#  array([ 1.98,  2.23,  0.13,  0.8 ]),
#  array([ 2.71,  0.61,  1.7 ,  0.11]),
#  array([ 3.59,  1.11,  0.05,  0.38]),
#  array([ 3.21,  1.53,  0.01,  0.38]),
#  array([ 3.22,  1.69,  0.  ,  0.2 ]),
#  array([ 3.81,  0.63,  0.  ,  0.68]),
#  array([ 1.96,  1.43,  1.08,  0.65]),
#  array([ 2.66,  2.01,  0.  ,  0.41]),
#  array([ 1.7 ,  2.02,  0.16,  1.21]),
#  array([ 0.6 ,  3.29,  0.06,  1.13]),
#  array([ 3.4 ,  1.3 ,  0.15,  0.22]),
#  array([ 2.05,  1.16,  1.11,  0.73]),
#  array([ 3.42,  1.38,  0.02,  0.2 ]),
#  array([ 2.59,  1.06,  0.8 ,  0.57]),
#  array([ 2.79,  1.89,  0.  ,  0.33]),
#  array([ 3.36,  1.36,  0.07,  0.21]),
#  array([ 3.06,  1.18,  0.29,  0.46]),
#  array([ 3.49,  0.01,  0.01,  1.48]),
#  array([ 3.39,  1.03,  0.09,  0.44]),
#  array([ 1.85,  1.2 ,  1.54,  0.37]),
#  array([ 2.31,  1.73,  0.12,  0.78]),
#  array([ 3.98,  0.26,  0.01,  0.66]),
#  array([ 2.89,  1.54,  0.  ,  0.46]),
#  array([ 2.91,  0.99,  0.89,  0.1 ]),
#  array([ 0.  ,  0.  ,  4.87,  0.  ]),
#  array([ 2.62,  0.6 ,  1.52,  0.1 ]),
#  array([ 2.74,  1.36,  0.12,  0.63]),
#  array([ 2.56,  1.68,  0.  ,  0.59]),
#  array([ 1.91,  2.  ,  0.09,  0.83]),
#  array([ 0.57,  3.14,  0.04,  1.07]),
#  array([ 2.57,  1.57,  0.44,  0.21]),
#  array([ 0.28,  3.75,  0.06,  0.69]),
#  array([ 2.99,  1.31,  0.04,  0.41]),
#  array([ 2.36,  2.1 ,  0.02,  0.25]),
#  array([ 1.73,  2.19,  0.  ,  0.79]),
#  array([ 3.05,  1.41,  0.02,  0.2 ]),
#  array([ 1.87,  1.12,  1.32,  0.37]),
#  array([ 1.94,  1.95,  0.08,  0.7 ]),
#  array([ 2.08,  2.04,  0.06,  0.47]),
#  array([ 2.29,  1.97,  0.13,  0.24]),
#  array([ 3.06,  1.12,  0.  ,  0.44]),
#  array([ 2.42,  0.91,  1.15,  0.13]),
#  array([ 2.6 ,  0.99,  0.89,  0.13]),
#  array([ 1.89,  1.99,  0.22,  0.48]),
#  array([ 1.78,  1.39,  1.1 ,  0.3 ]),
#  array([ 1.55,  1.15,  1.44,  0.43]),
#  array([ 1.78,  1.87,  0.07,  0.82]),
#  array([ 3.19,  0.92,  0.01,  0.42]),
#  array([ 4.18,  0.26,  0.01,  0.08]),
#  array([ 4.21,  0.24,  0.  ,  0.05]),
#  array([ 3.63,  0.24,  0.01,  0.61]),
#  array([ 2.71,  1.51,  0.03,  0.23]),
#  array([ 0.2 ,  0.14,  4.1 ,  0.02]),
#  array([ 1.96,  1.69,  0.08,  0.74]),
#  array([ 1.54,  1.94,  0.19,  0.77]),
#  array([ 2.71,  1.29,  0.02,  0.43]),
#  array([ 2.55,  1.11,  0.46,  0.33]),
#  array([ 2.67,  1.35,  0.01,  0.39]),
#  array([ 2.66,  1.29,  0.01,  0.46]),
#  array([ 0.1 ,  2.39,  1.05,  0.86]),
#  array([ 2.82,  1.05,  0.13,  0.4 ]),
#  array([ 2.19,  0.5 ,  1.61,  0.08]),
#  array([ 2.03,  1.79,  0.08,  0.47]),
#  array([ 1.73,  1.73,  0.14,  0.75]),
#  array([ 3.03,  0.91,  0.26,  0.13]),
#  array([ 2.2 ,  0.58,  1.38,  0.17]),
#  array([ 0.92,  2.93,  0.01,  0.46]),
#  array([ 2.75,  1.18,  0.  ,  0.37]),
#  array([ 4.  ,  0.26,  0.  ,  0.05]),
#  array([ 2.51,  1.27,  0.11,  0.41]),
#  array([ 2.64,  1.2 ,  0.03,  0.39]),
#  array([ 2.11,  1.11,  0.72,  0.3 ]),
#  array([ 2.23,  1.34,  0.07,  0.61]),
#  array([ 1.41,  2.02,  0.1 ,  0.72]),
#  array([ 3.  ,  1.11,  0.05,  0.07]),
#  array([ 1.46,  0.  ,  0.83,  1.93]),
#  array([ 2.45,  1.02,  0.  ,  0.75]),
#  array([ 1.7 ,  2.27,  0.  ,  0.23]),
#  array([ 2.03,  1.27,  0.62,  0.3 ]),
#  array([ 0.78,  2.55,  0.04,  0.84]),
#  array([ 0.88,  2.3 ,  0.2 ,  0.83]),
#  array([ 1.3 ,  2.07,  0.18,  0.65]),
#  array([ 1.28,  1.83,  0.57,  0.53]),
#  array([ 2.25,  1.47,  0.04,  0.43]),
#  array([ 2.02,  1.06,  0.58,  0.53]),
#  array([ 0.84,  2.79,  0.02,  0.53]),
#  array([ 3.38,  0.44,  0.31,  0.04]),
#  array([ 2.04,  0.48,  1.57,  0.07]),
#  array([ 3.79,  0.27,  0.  ,  0.11]),
#  array([ 3.36,  0.21,  0.01,  0.56]),
#  array([ 1.4 ,  1.86,  0.11,  0.77]),
#  array([ 4.03,  0.  ,  0.09,  0.  ]),
#  array([ 1.65,  0.61,  1.76,  0.09]),
#  array([ 0.71,  2.48,  0.03,  0.89]),
#  array([ 2.14,  1.2 ,  0.37,  0.4 ]),
#  array([ 1.42,  0.51,  2.1 ,  0.07]),
#  array([ 2.13,  1.5 ,  0.05,  0.42]),
#  array([ 2.45,  1.26,  0.01,  0.37]),
#  array([ 2.57,  1.52,  0.  ,  0.  ]),
#  array([ 2.65,  1.06,  0.04,  0.33]),
#  array([ 2.32,  0.04,  0.04,  1.67]),
#  array([ 2.35,  1.28,  0.03,  0.41]),
#  array([ 0.12,  2.26,  0.9 ,  0.77]),
#  array([ 2.28,  1.55,  0.16,  0.06]),
#  array([ 1.68,  1.51,  0.51,  0.35]),
#  array([ 1.12,  2.12,  0.1 ,  0.69]),
#  array([ 2.78,  0.58,  0.64,  0.04]),
#  array([ 1.38,  1.87,  0.12,  0.65]),
#  array([ 1.22,  0.28,  2.46,  0.04]),
#  array([ 2.15,  1.2 ,  0.07,  0.59]),
#  array([ 0.92,  1.78,  0.92,  0.37]),
#  array([ 2.67,  0.89,  0.05,  0.37]),
#  array([ 2.08,  1.35,  0.  ,  0.54]),
#  array([ 2.1 ,  1.36,  0.06,  0.4 ]),
#  array([ 1.18,  1.96,  0.08,  0.7 ]),
#  array([ 1.97,  0.76,  1.07,  0.11]),
#  array([ 2.29,  1.17,  0.01,  0.42]),
#  array([ 1.33,  1.71,  0.13,  0.73]),
#  array([ 0.67,  0.49,  2.62,  0.11]),
#  array([ 1.53,  1.61,  0.06,  0.67]),
#  array([ 1.15,  2.09,  0.  ,  0.64]),
#  array([ 0.93,  1.94,  0.31,  0.7 ]),
#  array([ 0.1 ,  0.  ,  3.77,  0.  ]),
#  array([ 2.12,  1.14,  0.1 ,  0.51]),
#  array([ 2.48,  0.65,  0.03,  0.69]),
#  array([ 0.16,  1.89,  1.12,  0.68]),
#  array([ 0.87,  1.57,  1.05,  0.35]),
#  array([ 2.12,  1.44,  0.22,  0.06]),
#  array([ 2.21,  0.96,  0.54,  0.13]),
#  array([ 2.26,  0.48,  0.81,  0.27]),
#  array([ 1.06,  1.93,  0.41,  0.43]),
#  array([ 1.44,  1.37,  0.73,  0.27]),
#  array([ 1.49,  1.58,  0.1 ,  0.61]),
#  array([ 1.14,  1.91,  0.27,  0.46]),
#  array([ 2.4 ,  1.03,  0.  ,  0.36]),
#  array([ 1.82,  1.24,  0.47,  0.25]),
#  array([ 1.4 ,  1.4 ,  0.1 ,  0.87]),
#  array([ 1.98,  1.47,  0.  ,  0.32]),
#  array([ 2.03,  1.56,  0.  ,  0.17]),
#  array([ 1.98,  0.88,  0.59,  0.32]),
#  array([ 1.37,  2.  ,  0.14,  0.22]),
#  array([ 0.96,  2.  ,  0.21,  0.56]),
#  array([ 1.3 ,  0.77,  1.54,  0.11]),
#  array([ 1.93,  1.58,  0.  ,  0.19]),
#  array([ 0.58,  2.48,  0.04,  0.59]),
#  array([ 1.49,  0.73,  1.38,  0.1 ]),
#  array([ 1.3 ,  1.51,  0.27,  0.61]),
#  array([ 1.59,  1.61,  0.08,  0.41]),
#  array([ 0.  ,  0.  ,  3.67,  0.  ]),
#  array([ 2.13,  1.18,  0.01,  0.35]),
#  array([ 1.65,  1.22,  0.  ,  0.79]),
#  array([ 1.87,  1.13,  0.55,  0.1 ]),
#  array([ 2.53,  0.81,  0.06,  0.24]),
#  array([ 2.33,  0.97,  0.  ,  0.35]),
#  array([ 0.71,  1.8 ,  0.4 ,  0.74]),
#  array([ 2.08,  1.09,  0.15,  0.33]),
#  array([ 2.23,  0.68,  0.66,  0.06]),
#  array([ 0.6 ,  2.46,  0.05,  0.52]),
#  array([ 0.05,  0.  ,  0.64,  2.93]),
#  array([ 1.78,  1.42,  0.05,  0.38]),
#  array([ 2.08,  0.83,  0.46,  0.25]),
#  array([ 1.28,  1.61,  0.15,  0.57]),
#  array([ 1.93,  1.22,  0.03,  0.44]),
#  array([ 2.05,  1.4 ,  0.  ,  0.16]),
#  array([ 2.02,  1.17,  0.  ,  0.42]),
#  array([ 1.61,  1.5 ,  0.1 ,  0.39]),
#  array([ 2.38,  0.67,  0.46,  0.1 ]),
#  array([ 2.18,  1.02,  0.03,  0.37]),
#  array([ 2.01,  1.35,  0.06,  0.16]),
#  array([ 1.57,  1.79,  0.  ,  0.2 ]),
#  array([ 1.56,  1.4 ,  0.07,  0.5 ]),
#  array([ 1.23,  1.77,  0.05,  0.49]),
#  array([ 1.66,  1.58,  0.12,  0.18]),
#  array([ 1.9 ,  1.13,  0.1 ,  0.41]),
#  array([ 1.98,  1.14,  0.01,  0.41]),
#  array([ 2.14,  1.08,  0.02,  0.29]),
#  array([ 0.71,  2.4 ,  0.02,  0.4 ]),
#  array([ 1.96,  1.33,  0.  ,  0.23]),
#  array([ 2.14,  1.21,  0.01,  0.17]),
#  array([ 2.66,  0.5 ,  0.05,  0.3 ]),
#  array([ 1.22,  1.66,  0.27,  0.38]),
#  array([ 2.11,  0.94,  0.12,  0.34]),
#  array([ 1.17,  0.5 ,  1.75,  0.08]),
#  array([ 2.84,  0.39,  0.03,  0.24]),
#  array([ 1.64,  0.38,  1.42,  0.06]),
#  array([ 2.2 ,  0.97,  0.02,  0.31]),
#  array([ 0.59,  1.83,  0.73,  0.35]),
#  array([ 0.59,  2.36,  0.04,  0.51]),
#  array([ 1.94,  1.22,  0.02,  0.31]),
#  array([ 2.09,  1.02,  0.04,  0.32]),
#  array([ 2.11,  1.01,  0.01,  0.35]),
#  array([ 2.26,  0.89,  0.  ,  0.3 ]),
#  array([ 0.88,  1.75,  0.1 ,  0.72]),
#  array([ 0.  ,  0.  ,  3.44,  0.  ]),
#  array([ 2.39,  0.73,  0.03,  0.29]),
#  array([ 1.55,  1.27,  0.33,  0.29]),
#  array([ 1.34,  1.54,  0.17,  0.38]),
#  array([ 1.82,  1.07,  0.06,  0.47]),
#  array([ 1.13,  2.07,  0.  ,  0.22]),
#  array([ 0.86,  0.  ,  2.55,  0.02]),
#  array([ 1.75,  1.2 ,  0.02,  0.43]),
#  array([ 1.73,  0.69,  0.59,  0.4 ]),
#  array([ 0.46,  2.28,  0.05,  0.61]),
#  array([ 1.56,  1.47,  0.19,  0.17]),
#  array([ 2.03,  1.03,  0.  ,  0.32]),
#  array([ 1.08,  1.35,  0.48,  0.47]),
#  array([ 1.43,  0.94,  0.74,  0.27]),
#  array([ 2.47,  0.76,  0.  ,  0.13]),
#  array([ 1.9 ,  0.67,  0.73,  0.06]),
#  array([ 0.65,  1.61,  0.82,  0.28]),
#  array([ 1.63,  1.53,  0.  ,  0.18]),
#  array([ 1.9 ,  1.14,  0.01,  0.29]),
#  array([ 0.  ,  0.99,  2.32,  0.02]),
#  array([ 1.45,  1.29,  0.12,  0.46]),
#  array([ 1.44,  1.01,  0.57,  0.3 ]),
#  array([ 1.15,  1.17,  0.76,  0.24]),
#  array([ 1.47,  1.39,  0.03,  0.43]),
#  array([ 1.99,  1.05,  0.05,  0.22]),
#  array([ 1.5 ,  1.28,  0.05,  0.46]),
#  array([ 0.8 ,  1.92,  0.06,  0.5 ]),
#  array([ 2.13,  0.92,  0.  ,  0.23]),
#  array([ 1.89,  1.05,  0.02,  0.31]),
#  array([ 1.36,  1.13,  0.46,  0.32]),
#  array([ 0.5 ,  1.59,  0.31,  0.87]),
#  array([ 0.25,  0.19,  2.78,  0.04]),
#  array([ 0.95,  1.3 ,  0.77,  0.22]),
#  array([ 0.88,  2.11,  0.  ,  0.23]),
#  array([ 1.27,  1.33,  0.12,  0.51]),
#  array([ 2.33,  0.3 ,  0.  ,  0.59]),
#  array([ 0.03,  0.  ,  3.18,  0.  ]),
#  array([ 1.72,  1.33,  0.  ,  0.16]),
#  array([ 0.73,  0.1 ,  2.35,  0.02]),
#  array([ 2.26,  0.72,  0.12,  0.1 ]),
#  array([ 1.76,  1.21,  0.07,  0.16]),
#  array([ 1.35,  0.6 ,  0.8 ,  0.44]),
#  array([ 1.48,  1.01,  0.04,  0.66]),
#  array([ 0.  ,  0.  ,  3.19,  0.  ]),
#  array([ 2.15,  0.77,  0.01,  0.26]),
#  array([ 1.78,  1.12,  0.09,  0.19]),
#  array([ 1.18,  0.87,  0.93,  0.2 ]),
#  array([ 1.52,  1.08,  0.1 ,  0.47]),
#  array([ 1.86,  1.02,  0.  ,  0.29]),
#  array([ 0.58,  0.51,  1.93,  0.14]),
#  array([ 2.06,  0.56,  0.38,  0.17]),
#  array([ 1.88,  0.98,  0.  ,  0.3 ]),
#  array([ 1.92,  0.16,  0.99,  0.09]),
#  array([ 1.79,  1.06,  0.  ,  0.29]),
#  array([ 1.22,  1.57,  0.06,  0.29]),
#  array([ 0.88,  0.97,  0.88,  0.42]),
#  array([ 1.89,  0.99,  0.03,  0.24]),
#  array([ 0.68,  0.  ,  0.  ,  2.46]),
#  array([ 1.7 ,  1.25,  0.02,  0.16]),
#  array([ 2.14,  0.86,  0.  ,  0.13]),
#  array([ 2.31,  0.62,  0.14,  0.04]),
#  array([ 0.91,  1.  ,  1.03,  0.17]),
#  array([ 1.69,  0.87,  0.14,  0.42]),
#  array([ 0.08,  0.  ,  3.03,  0.01]),
#  array([ 1.29,  1.27,  0.06,  0.5 ]),
#  array([ 1.99,  0.82,  0.03,  0.27]),
#  array([ 0.78,  2.02,  0.  ,  0.3 ]),
#  array([ 2.17,  0.28,  0.55,  0.08]),
#  array([ 2.5 ,  0.16,  0.01,  0.42]),
#  array([ 1.92,  0.45,  0.64,  0.07]),
#  array([ 1.89,  0.91,  0.04,  0.24]),
#  array([ 1.4 ,  0.99,  0.46,  0.22]),
#  array([ 1.57,  0.62,  0.55,  0.34]),
#  array([ 1.72,  1.21,  0.  ,  0.14]),
#  array([ 1.94,  0.86,  0.03,  0.24]),
#  array([ 1.91,  0.84,  0.  ,  0.29]),
#  array([ 1.38,  1.35,  0.02,  0.28]),
#  array([ 2.06,  0.64,  0.12,  0.22]),
#  array([ 1.94,  0.8 ,  0.02,  0.27]),
#  array([ 1.54,  1.33,  0.  ,  0.16]),
#  array([ 1.4 ,  1.07,  0.08,  0.47]),
#  array([ 1.85,  1.04,  0.  ,  0.13]),
#  array([ 2.03,  0.47,  0.45,  0.07]),
#  array([ 1.45,  1.13,  0.07,  0.38]),
#  array([ 2.38,  0.32,  0.  ,  0.31]),
#  array([ 2.6 ,  0.21,  0.01,  0.19]),
#  array([ 1.15,  0.  ,  0.76,  1.09]),
#  array([ 1.57,  1.02,  0.  ,  0.41]),
#  array([ 1.01,  1.41,  0.05,  0.53]),
#  array([ 1.61,  0.51,  0.8 ,  0.07]),
#  array([ 1.67,  1.18,  0.  ,  0.13]),
#  array([ 0.12,  1.26,  1.16,  0.45]),
#  array([ 1.36,  0.86,  0.64,  0.13]),
#  array([ 0.47,  1.  ,  1.39,  0.12]),
#  array([ 1.33,  1.12,  0.08,  0.45]),
#  array([ 0.96,  1.72,  0.  ,  0.29]),
#  array([ 1.58,  1.01,  0.  ,  0.38]),
#  array([ 1.04,  1.37,  0.06,  0.49]),
#  array([ 1.57,  0.04,  1.19,  0.15]),
#  array([ 1.36,  1.15,  0.04,  0.41]),
#  array([ 1.82,  0.71,  0.15,  0.26]),
#  array([ 1.98,  0.58,  0.34,  0.04]),
#  array([ 2.22,  0.51,  0.06,  0.15]),
#  array([ 1.45,  1.11,  0.04,  0.33]),
#  array([ 1.76,  0.69,  0.12,  0.37]),
#  array([ 2.07,  0.77,  0.05,  0.05]),
#  array([ 1.83,  0.8 ,  0.03,  0.27]),
#  array([ 0.87,  1.06,  0.73,  0.26]),
#  array([ 1.43,  1.13,  0.05,  0.3 ]),
#  array([ 1.75,  0.45,  0.62,  0.09]),
#  array([ 0.61,  1.85,  0.11,  0.33]),
#  array([ 1.84,  0.8 ,  0.04,  0.22]),
#  array([ 1.54,  1.14,  0.  ,  0.22]),
#  array([ 1.75,  0.86,  0.  ,  0.28]),
#  array([ 0.08,  1.24,  1.13,  0.45]),
#  array([ 0.71,  1.51,  0.06,  0.61]),
#  array([ 0.99,  0.32,  1.38,  0.2 ]),
#  array([ 1.51,  1.12,  0.01,  0.24]),
#  array([ 1.54,  1.07,  0.  ,  0.28]),
#  array([ 2.03,  0.72,  0.02,  0.11]),
#  array([ 1.3 ,  1.27,  0.  ,  0.31]),
#  array([ 0.09,  2.43,  0.12,  0.22]),
#  array([ 1.87,  0.77,  0.  ,  0.22]),
#  array([ 2.53,  0.16,  0.  ,  0.17]),
#  array([ 2.09,  0.63,  0.03,  0.11]),
#  array([ 1.98,  0.55,  0.  ,  0.32]),
#  array([ 1.37,  0.51,  0.89,  0.07]),
#  array([ 1.29,  0.53,  0.98,  0.05]),
#  array([ 1.37,  1.34,  0.  ,  0.14]),
#  array([ 1.4 ,  1.14,  0.  ,  0.31]),
#  array([ 0.4 ,  1.98,  0.05,  0.42]),
#  array([ 1.87,  0.57,  0.11,  0.3 ]),
#  array([ 1.65,  0.86,  0.05,  0.28]),
#  array([ 2.52,  0.09,  0.  ,  0.22]),
#  array([ 1.28,  1.05,  0.07,  0.43]),
#  array([ 1.32,  1.08,  0.04,  0.39]),
#  array([ 1.96,  0.67,  0.1 ,  0.09]),
#  array([ 1.59,  1.05,  0.04,  0.14]),
#  array([ 0.02,  2.79,  0.  ,  0.  ]),
#  array([ 1.05,  1.25,  0.03,  0.48]),
#  array([ 1.32,  1.19,  0.  ,  0.3 ]),
#  array([ 1.32,  1.06,  0.04,  0.38]),
#  array([ 1.74,  0.8 ,  0.  ,  0.26]),
#  array([ 1.47,  0.07,  1.1 ,  0.15]),
#  array([ 0.29,  0.2 ,  2.13,  0.18]),
#  array([ 1.45,  0.88,  0.09,  0.38]),
#  array([ 1.96,  0.72,  0.  ,  0.11]),
#  array([ 1.19,  1.15,  0.04,  0.41]),
#  array([ 0.  ,  0.  ,  2.78,  0.01]),
#  array([ 1.98,  0.7 ,  0.  ,  0.11]),
#  array([ 0.89,  1.43,  0.  ,  0.48]),
#  array([ 2.19,  0.22,  0.  ,  0.38]),
#  array([ 0.3 ,  1.47,  0.68,  0.34]),
#  array([ 0.46,  0.29,  1.96,  0.07]),
#  array([ 1.68,  0.74,  0.  ,  0.36]),
#  array([ 1.27,  0.97,  0.07,  0.47]),
#  array([ 1.44,  0.83,  0.26,  0.25]),
#  array([ 1.2 ,  0.98,  0.17,  0.43]),
#  array([ 1.41,  1.12,  0.  ,  0.24]),
#  array([ 1.24,  1.2 ,  0.04,  0.3 ]),
#  array([ 1.25,  1.15,  0.07,  0.3 ]),
#  array([ 2.56,  0.17,  0.  ,  0.03]),
#  array([ 1.43,  0.54,  0.71,  0.07]),
#  array([ 1.07,  1.31,  0.06,  0.31]),
#  array([ 1.02,  0.36,  1.13,  0.23]),
#  array([ 1.33,  0.31,  1.04,  0.05]),
#  array([ 1.52,  0.94,  0.02,  0.24]),
#  array([ 1.49,  0.93,  0.02,  0.27]),
#  array([ 1.75,  0.52,  0.33,  0.1 ]),
#  array([ 0.99,  0.48,  1.09,  0.14]),
#  array([ 1.47,  0.76,  0.  ,  0.47]),
#  array([ 1.25,  0.53,  0.87,  0.05]),
#  array([ 2.42,  0.11,  0.  ,  0.16]),
#  array([ 1.85,  0.64,  0.01,  0.19]),
#  array([ 2.38,  0.12,  0.  ,  0.18]),
#  array([ 1.63,  0.52,  0.35,  0.18]),
#  array([ 1.46,  0.98,  0.  ,  0.24]),
#  array([ 1.23,  1.11,  0.  ,  0.34]),
#  array([ 0.  ,  0.  ,  2.68,  0.  ]),
#  array([ 0.69,  1.41,  0.04,  0.53]),
#  array([ 0.78,  0.75,  0.89,  0.26]),
#  array([ 1.95,  0.63,  0.  ,  0.09]),
#  array([ 1.48,  0.92,  0.01,  0.26]),
#  array([ 1.78,  0.64,  0.  ,  0.25]),
#  array([ 1.44,  1.09,  0.  ,  0.14]),
#  array([ 1.99,  0.58,  0.  ,  0.09]),
#  array([ 1.59,  0.8 ,  0.  ,  0.26]),
#  array([ 1.15,  1.11,  0.  ,  0.4 ]),
#  array([ 1.56,  0.88,  0.  ,  0.22]),
#  array([ 0.86,  1.11,  0.01,  0.66]),
#  array([ 0.  ,  0.  ,  2.65,  0.  ]),
#  array([ 2.  ,  0.5 ,  0.12,  0.03]),
#  array([ 1.53,  0.87,  0.  ,  0.24]),
#  array([ 2.  ,  0.47,  0.02,  0.14]),
#  array([ 0.76,  1.1 ,  0.12,  0.65]),
#  array([ 1.53,  0.82,  0.04,  0.24]),
#  array([ 1.7 ,  0.46,  0.06,  0.41]),
#  array([ 2.15,  0.12,  0.  ,  0.36]),
#  array([ 1.07,  1.06,  0.24,  0.25]),
#  array([ 1.55,  0.81,  0.04,  0.21]),
#  array([ 0.59,  1.79,  0.01,  0.23]),
#  array([ 2.31,  0.14,  0.01,  0.16]),
#  array([ 0.63,  0.84,  0.96,  0.19]),
#  array([ 0.9 ,  1.22,  0.04,  0.44]),
#  array([ 1.02,  0.52,  0.92,  0.14]),
#  array([ 1.86,  0.55,  0.11,  0.08]),
#  array([ 0.48,  1.63,  0.04,  0.43]),
#  array([ 0.93,  1.12,  0.08,  0.45]),
#  array([ 2.03,  0.21,  0.  ,  0.35]),
#  array([ 0.64,  1.24,  0.01,  0.69]),
#  array([ 0.89,  1.33,  0.07,  0.28]),
#  array([ 1.04,  1.24,  0.03,  0.27]),
#  array([ 0.37,  0.27,  1.75,  0.18]),
#  array([ 1.4 ,  0.88,  0.03,  0.26]),
#  array([ 1.31,  0.74,  0.31,  0.22]),
#  array([ 0.28,  1.68,  0.33,  0.28]),
#  array([ 1.76,  0.56,  0.03,  0.22]),
#  array([ 2.14,  0.08,  0.  ,  0.35]),
#  array([ 1.7 ,  0.59,  0.21,  0.07]),
#  array([ 0.15,  0.  ,  2.41,  0.  ]),
#  array([ 2.11,  0.23,  0.  ,  0.22]),
#  array([ 1.21,  0.57,  0.7 ,  0.07]),
#  array([ 1.13,  0.87,  0.29,  0.25]),
#  array([ 2.21,  0.12,  0.  ,  0.2 ]),
#  array([ 2.36,  0.14,  0.  ,  0.03]),
#  array([ 1.13,  1.12,  0.06,  0.22]),
#  array([ 1.55,  0.75,  0.16,  0.06]),
#  array([ 1.5 ,  0.78,  0.  ,  0.24]),
#  array([ 0.49,  0.  ,  0.52,  1.51]),
#  array([ 0.6 ,  1.31,  0.08,  0.52]),
#  array([ 2.29,  0.02,  0.  ,  0.19]),
#  array([ 0.13,  0.07,  0.26,  2.05]),
#  array([ 1.28,  0.14,  1.08,  0.01]),
#  array([ 0.86,  1.06,  0.18,  0.39]),
#  array([ 1.84,  0.56,  0.  ,  0.09]),
#  array([ 1.29,  0.97,  0.  ,  0.23]),
#  array([ 1.81,  0.52,  0.  ,  0.15]),
#  array([ 1.15,  0.85,  0.1 ,  0.39]),
#  array([ 1.38,  0.85,  0.  ,  0.25]),
#  array([ 1.15,  1.14,  0.06,  0.13]),
#  array([ 1.72,  0.44,  0.05,  0.27]),
#  array([ 1.93,  0.34,  0.  ,  0.21]),
#  array([ 2.1 ,  0.2 ,  0.  ,  0.17]),
#  array([ 1.13,  0.36,  0.92,  0.07]),
#  array([ 1.67,  0.58,  0.  ,  0.2 ]),
#  array([ 1.55,  0.54,  0.05,  0.31]),
#  array([ 0.  ,  0.  ,  2.43,  0.02]),
#  array([ 0.93,  0.12,  1.34,  0.06]),
#  array([ 2.12,  0.25,  0.  ,  0.07]),
#  array([ 1.44,  0.73,  0.04,  0.22]),
#  array([ 0.87,  0.98,  0.  ,  0.59]),
#  array([ 1.07,  1.19,  0.  ,  0.18]),
#  array([ 1.52,  0.82,  0.  ,  0.1 ]),
#  array([ 1.56,  0.61,  0.02,  0.23]),
#  array([ 1.26,  0.61,  0.46,  0.08]),
#  array([ 1.27,  0.32,  0.78,  0.05]),
#  array([ 0.29,  1.18,  0.54,  0.41]),
#  array([ 1.63,  0.22,  0.51,  0.06]),
#  array([ 2.07,  0.26,  0.  ,  0.08]),
#  array([ 0.81,  0.76,  0.7 ,  0.14]),
#  array([ 1.43,  0.76,  0.  ,  0.22]),
#  array([ 0.69,  0.  ,  0.04,  1.68]),
#  array([ 2.07,  0.08,  0.  ,  0.26]),
#  array([ 2.1 ,  0.24,  0.  ,  0.07]),
#  array([ 0.77,  0.18,  1.42,  0.03]),
#  array([ 2.3,  0.1,  0. ,  0. ]),
#  array([ 2.15,  0.18,  0.  ,  0.07]),
#  array([ 0.49,  1.49,  0.05,  0.36]),
#  array([ 1.74,  0.48,  0.  ,  0.18]),
#  array([ 1.54,  0.63,  0.  ,  0.22]),
#  array([ 1.49,  0.81,  0.  ,  0.1 ]),
#  array([ 1.07,  0.87,  0.04,  0.4 ]),
#  array([ 1.48,  0.71,  0.  ,  0.2 ]),
#  array([ 1.67,  0.61,  0.03,  0.07]),
#  array([ 1.02,  0.97,  0.  ,  0.39]),
#  array([ 1.73,  0.46,  0.02,  0.18]),
#  array([ 1.94,  0.39,  0.03,  0.02]),
#  array([ 1.  ,  0.76,  0.26,  0.36]),
#  array([ 1.46,  0.54,  0.01,  0.37]),
#  array([ 2.04,  0.15,  0.  ,  0.19]),
#  array([ 1.16,  0.91,  0.  ,  0.3 ]),
#  array([ 2.18,  0.01,  0.  ,  0.18]),
#  array([ 2.28,  0.02,  0.08,  0.  ]),
#  array([ 0.96,  1.08,  0.04,  0.3 ]),
#  array([ 1.25,  0.86,  0.01,  0.26]),
#  array([ 2.03,  0.13,  0.  ,  0.21]),
#  array([ 1.38,  0.74,  0.02,  0.22]),
#  array([ 0.69,  0.14,  1.48,  0.05]),
#  array([ 1.07,  1.05,  0.  ,  0.23]),
#  array([ 1.39,  0.48,  0.4 ,  0.08]),
#  array([ 0.  ,  0.  ,  2.34,  0.01]),
#  array([ 1.68,  0.46,  0.01,  0.2 ]),
#  array([ 1.32,  0.83,  0.  ,  0.2 ]),
#  array([ 0.92,  0.  ,  0.01,  1.41]),
#  array([ 1.2 ,  0.9 ,  0.  ,  0.24]),
#  array([ 1.08,  0.7 ,  0.34,  0.21]),
#  array([ 1.27,  0.86,  0.  ,  0.2 ]),
#  array([ 1.14,  0.54,  0.47,  0.17]),
#  array([ 1.93,  0.14,  0.  ,  0.24]),
#  array([ 1.57,  0.56,  0.  ,  0.19]),
#  array([ 0.78,  0.4 ,  1.06,  0.07]),
#  array([ 0.79,  1.35,  0.04,  0.14]),
#  array([ 0.85,  1.06,  0.09,  0.32]),
#  array([ 0.52,  0.45,  1.21,  0.13]),
#  array([ 1.58,  0.64,  0.  ,  0.09]),
#  array([ 0.28,  0.  ,  2.02,  0.01]),
#  array([ 1.65,  0.46,  0.1 ,  0.1 ]),
#  array([ 1.24,  0.85,  0.  ,  0.21]),
#  array([ 0.95,  1.06,  0.  ,  0.29]),
#  array([ 0.95,  0.54,  0.62,  0.18]),
#  array([ 1.08,  0.75,  0.15,  0.31]),
#  array([ 0.91,  1.25,  0.  ,  0.13]),
#  array([ 1.23,  0.68,  0.04,  0.34]),
#  array([ 1.38,  0.8 ,  0.  ,  0.1 ]),
#  array([ 0.3 ,  1.27,  0.46,  0.26]),
#  array([ 1.11,  0.98,  0.  ,  0.2 ]),
#  array([ 0.  ,  0.  ,  2.28,  0.  ]),
#  array([ 0.51,  0.12,  1.63,  0.02]),
#  array([ 0.38,  0.07,  0.01,  1.82]),
#  array([ 1.01,  0.9 ,  0.  ,  0.37]),
#  array([ 1.05,  0.77,  0.1 ,  0.36]),
#  array([ 0.07,  2.  ,  0.02,  0.18]),
#  array([ 1.12,  0.39,  0.64,  0.12]),
#  array([ 1.34,  0.62,  0.  ,  0.31]),
#  array([ 1.07,  0.92,  0.04,  0.24]),
#  array([ 1.22,  0.1 ,  0.91,  0.04]),
#  array([ 0.9 ,  0.73,  0.54,  0.09]),
#  array([ 1.4 ,  0.54,  0.02,  0.3 ]),
#  array([ 1.19,  0.84,  0.  ,  0.23]),
#  array([ 1.34,  0.57,  0.14,  0.21]),
#  array([ 0.28,  0.79,  0.87,  0.32]),
#  array([ 0.62,  0.44,  1.06,  0.13]),
#  array([ 1.52,  0.46,  0.2 ,  0.08]),
#  array([ 1.48,  0.25,  0.46,  0.06]),
#  array([ 1.93,  0.15,  0.  ,  0.17]),
#  array([ 0.67,  0.41,  1.05,  0.11]),
#  array([ 0.51,  0.51,  0.91,  0.32]),
#  array([ 1.19,  0.71,  0.22,  0.13]),
#  array([ 1.29,  0.83,  0.  ,  0.11]),
#  array([ 1.74,  0.25,  0.21,  0.03]),
#  array([ 1.42,  0.61,  0.  ,  0.21]),
#  array([ 1.09,  0.85,  0.  ,  0.28]),
#  array([ 1.27,  0.62,  0.18,  0.16]),
#  array([ 0.88,  1.03,  0.  ,  0.31]),
#  array([ 1.71,  0.32,  0.02,  0.18]),
#  array([ 1.  ,  0.63,  0.45,  0.13]),
#  array([ 1.03,  0.98,  0.  ,  0.21]),
#  array([ 1.45,  0.55,  0.02,  0.19]),
#  array([ 1.47,  0.55,  0.  ,  0.19]),
#  array([ 1.06,  0.82,  0.05,  0.28]),
#  array([ 1.78,  0.24,  0.  ,  0.18]),
#  array([ 2.06,  0.12,  0.  ,  0.02]),
#  array([ 2.01,  0.02,  0.  ,  0.17]),
#  array([ 1.11,  0.51,  0.34,  0.23]),
#  array([ 0.15,  0.  ,  2.05,  0.  ]),
#  array([ 1.28,  0.68,  0.02,  0.21]),
#  array([ 1.06,  0.91,  0.  ,  0.23]),
#  array([ 0.34,  0.97,  0.55,  0.33]),
#  array([ 1.17,  0.78,  0.02,  0.22]),
#  array([ 1.68,  0.44,  0.  ,  0.08]),
#  array([ 0.87,  0.17,  1.1 ,  0.05]),
#  array([ 1.04,  0.72,  0.3 ,  0.13]),
#  array([ 0.59,  1.07,  0.07,  0.45]),
#  array([ 0.  ,  0.  ,  2.17,  0.01]),
#  array([ 1.92,  0.2 ,  0.  ,  0.06]),
#  array([ 1.21,  0.78,  0.01,  0.17]),
#  array([ 1.97,  0.07,  0.  ,  0.13]),
#  array([ 1.29,  0.04,  0.73,  0.12]),
#  array([ 1.48,  0.17,  0.47,  0.06]),
#  array([ 1.27,  0.68,  0.01,  0.2 ]),
#  array([ 1.6 ,  0.46,  0.08,  0.03]),
#  array([ 0.48,  0.11,  1.56,  0.02]),
#  array([ 1.23,  0.83,  0.  ,  0.1 ]),
#  array([ 1.51,  0.47,  0.  ,  0.18]),
#  array([ 1.5 ,  0.55,  0.02,  0.08]),
#  array([ 0.54,  1.16,  0.13,  0.32]),
#  array([ 0.14,  0.03,  1.98,  0.  ]),
#  array([ 0.6 ,  1.41,  0.  ,  0.14]),
#  array([ 0.52,  1.03,  0.  ,  0.59]),
#  array([ 0.66,  0.  ,  1.45,  0.03]),
#  array([ 0.01,  0.  ,  2.13,  0.  ]),
#  array([ 1.47,  0.38,  0.19,  0.1 ]),
#  array([ 1.2 ,  0.84,  0.  ,  0.1 ]),
#  array([ 1.99,  0.12,  0.  ,  0.02]),
#  array([ 1.04,  0.81,  0.  ,  0.27]),
#  array([ 0.64,  0.07,  1.35,  0.08]),
#  array([ 0.82,  0.37,  0.89,  0.05]),
#  array([ 0.59,  1.16,  0.06,  0.33]),
#  array([ 0.93,  0.97,  0.02,  0.21]),
#  array([ 0.91,  0.05,  1.07,  0.09]),
#  array([ 1.47,  0.09,  0.45,  0.11]),
#  array([ 1.37,  0.61,  0.05,  0.09]),
#  array([ 0.83,  0.33,  0.92,  0.04]),
#  array([ 1.61,  0.27,  0.05,  0.18]),
#  array([ 1.2 ,  0.62,  0.  ,  0.29]),
#  array([ 1.68,  0.4 ,  0.  ,  0.03]),
#  array([ 0.11,  1.34,  0.4 ,  0.26]),
#  array([ 1.68,  0.31,  0.02,  0.09]),
#  array([ 0.9 ,  0.45,  0.63,  0.13]),
#  array([ 1.35,  0.56,  0.  ,  0.2 ]),
#  array([ 0.63,  0.21,  1.13,  0.13]),
#  array([ 1.63,  0.33,  0.  ,  0.15]),
#  array([ 0.94,  0.07,  1.05,  0.04]),
#  array([ 1.17,  0.72,  0.  ,  0.22]),
#  array([ 1.54,  0.44,  0.04,  0.07]),
#  array([ 1.77,  0.13,  0.02,  0.18]),
#  array([ 1.41,  0.51,  0.01,  0.17]),
#  array([ 0.99,  0.63,  0.29,  0.19]),
#  array([ 0.  ,  0.  ,  1.96,  0.14]),
#  array([ 1.16,  0.65,  0.08,  0.2 ]),
#  array([ 1.26,  0.6 ,  0.05,  0.18]),
#  array([ 1.84,  0.12,  0.01,  0.13]),
#  array([ 1.97,  0.  ,  0.  ,  0.12]),
#  array([ 0.92,  0.94,  0.  ,  0.22]),
#  array([ 0.7 ,  0.93,  0.14,  0.32]),
#  array([ 0.46,  0.42,  0.96,  0.25]),
#  array([ 1.77,  0.32,  0.  ,  0.  ]),
#  array([ 1.11,  0.71,  0.  ,  0.27]),
#  array([ 0.63,  1.02,  0.05,  0.39]),
#  array([ 1.36,  0.52,  0.  ,  0.2 ]),
#  array([ 0.97,  0.33,  0.73,  0.06]),
#  array([ 0.59,  0.99,  0.13,  0.36]),
#  array([ 2.04,  0.04,  0.  ,  0.  ]),
#  array([ 0.89,  1.08,  0.  ,  0.11]),
#  array([ 0.79,  0.94,  0.  ,  0.35]),
#  array([ 1.54,  0.46,  0.  ,  0.08]),
#  array([ 0.63,  0.42,  0.75,  0.26]),
#  array([ 1.48,  0.39,  0.  ,  0.19]),
#  array([ 0.75,  0.54,  0.54,  0.23]),
#  array([ 1.64,  0.36,  0.  ,  0.07]),
#  array([ 1.04,  0.8 ,  0.01,  0.22]),
#  array([ 0.73,  0.97,  0.02,  0.34]),
#  array([ 1.2 ,  0.63,  0.04,  0.19]),
#  array([ 0.71,  0.52,  0.74,  0.08]),
#  array([ 1.15,  0.77,  0.04,  0.1 ]),
#  array([ 0.68,  0.46,  0.79,  0.13]),
#  array([ 1.06,  0.62,  0.13,  0.25]),
#  array([ 0.89,  0.57,  0.46,  0.13]),
#  array([ 0.73,  0.92,  0.04,  0.37]),
#  array([ 1.23,  0.64,  0.  ,  0.19]),
#  array([ 1.43,  0.33,  0.04,  0.25]),
#  array([ 1.16,  0.06,  0.83,  0.  ]),
#  array([ 1.47,  0.48,  0.05,  0.06]),
#  array([ 0.71,  0.83,  0.15,  0.35]),
#  array([ 1.75,  0.25,  0.  ,  0.05]),
#  array([ 0.48,  1.29,  0.02,  0.25]),
#  array([ 1.11,  0.27,  0.53,  0.14]),
#  array([ 1.45,  0.42,  0.01,  0.16]),
#  array([ 0.73,  1.09,  0.  ,  0.23]),
#  array([ 1.74,  0.02,  0.  ,  0.28]),
#  array([ 0.71,  1.02,  0.  ,  0.31]),
#  array([ 1.2 ,  0.48,  0.29,  0.07]),
#  array([ 0.58,  1.06,  0.03,  0.37]),
#  array([ 1.53,  0.25,  0.  ,  0.25]),
#  array([ 1.25,  0.61,  0.13,  0.05]),
#  array([ 1.47,  0.4 ,  0.  ,  0.16]),
#  array([ 1.57,  0.18,  0.  ,  0.27]),
#  array([ 1.05,  0.67,  0.  ,  0.3 ]),
#  array([ 1.81,  0.05,  0.01,  0.15]),
#  array([ 1.76,  0.09,  0.  ,  0.17]),
#  array([ 0.82,  0.98,  0.04,  0.18]),
#  array([ 0.49,  1.27,  0.  ,  0.25]),
#  array([ 1.2 ,  0.62,  0.  ,  0.18]),
#  array([ 0.77,  0.85,  0.01,  0.37]),
#  array([ 0.89,  0.45,  0.53,  0.13]),
#  array([ 0.35,  1.31,  0.02,  0.33]),
#  array([ 0.52,  0.16,  1.29,  0.03]),
#  array([ 1.48,  0.3 ,  0.  ,  0.22]),
#  array([ 0.95,  0.64,  0.27,  0.13]),
#  array([ 0.75,  0.3 ,  0.9 ,  0.04]),
#  array([ 1.21,  0.64,  0.05,  0.09]),
#  array([ 0.75,  1.09,  0.02,  0.12]),
#  array([ 0.93,  0.27,  0.75,  0.04]),
#  array([ 1.25,  0.58,  0.  ,  0.16]),
#  array([ 1.11,  0.63,  0.07,  0.16]),
#  array([ 0.72,  0.86,  0.08,  0.32]),
#  array([ 0.99,  0.8 ,  0.  ,  0.18]),
#  array([ 0.74,  0.95,  0.  ,  0.28]),
#  array([ 1.2 ,  0.59,  0.  ,  0.19]),
#  array([ 0.71,  0.58,  0.51,  0.17]),
#  array([ 1.01,  0.64,  0.02,  0.3 ]),
#  array([ 1.84,  0.11,  0.  ,  0.02]),
#  array([ 1.22,  0.57,  0.02,  0.15]),
#  array([ 0.5 ,  0.5 ,  0.63,  0.33]),
#  array([ 1.13,  0.37,  0.41,  0.05]),
#  array([ 0.18,  0.23,  1.53,  0.02]),
#  array([ 0.79,  0.03,  1.05,  0.08]),
#  array([ 1.09,  0.65,  0.02,  0.2 ]),
#  array([ 1.3 ,  0.49,  0.  ,  0.16]),
#  array([ 0.74,  1.01,  0.  ,  0.2 ]),
#  array([ 1.26,  0.61,  0.  ,  0.09]),
#  array([ 1.09,  0.77,  0.  ,  0.09]),
#  array([ 1.69,  0.2 ,  0.  ,  0.06]),
#  array([ 0.95,  0.74,  0.  ,  0.25]),
#  array([ 0.49,  1.26,  0.01,  0.18]),
#  array([ 1.94,  0.  ,  0.  ,  0.  ]),
#  array([ 0.59,  1.23,  0.  ,  0.13]),
#  array([ 0.96,  0.38,  0.55,  0.05]),
#  array([ 1.09,  0.15,  0.65,  0.04]),
#  array([ 1.41,  0.42,  0.03,  0.07]),
#  array([ 1.42,  0.4 ,  0.  ,  0.12]),
#  array([ 1.  ,  0.72,  0.  ,  0.21]),
#  array([ 1.15,  0.61,  0.  ,  0.17]),
#  array([ 1.1 ,  0.56,  0.  ,  0.27]),
#  array([ 1.48,  0.39,  0.  ,  0.06]),
#  array([ 0.34,  0.26,  1.3 ,  0.03]),
#  array([ 1.06,  0.6 ,  0.2 ,  0.07]),
#  array([ 1.53,  0.24,  0.  ,  0.16]),
#  array([ 0.56,  0.89,  0.1 ,  0.37]),
#  array([ 1.51,  0.  ,  0.29,  0.12]),
#  array([ 0.86,  0.87,  0.01,  0.17]),
#  array([ 0.92,  0.53,  0.41,  0.06]),
#  array([ 0.73,  0.97,  0.01,  0.22]),
#  array([ 0.87,  0.85,  0.  ,  0.2 ]),
#  array([ 0.76,  0.96,  0.  ,  0.2 ]),
#  array([ 1.03,  0.8 ,  0.  ,  0.09]),
#  array([ 0.94,  0.73,  0.  ,  0.25]),
#  array([ 0.26,  0.16,  1.46,  0.03]),
#  array([ 1.06,  0.67,  0.  ,  0.18]),
#  array([ 0.72,  0.16,  1.01,  0.02]),
#  array([ 1.14,  0.57,  0.  ,  0.19]),
#  array([ 1.3 ,  0.44,  0.  ,  0.17]),
#  array([ 0.77,  0.78,  0.04,  0.31]),
#  array([ 1.08,  0.66,  0.  ,  0.17]),
#  array([ 1.03,  0.75,  0.03,  0.09]),
#  array([ 0.59,  0.92,  0.06,  0.32]),
#  array([ 0.73,  0.91,  0.03,  0.22]),
#  array([ 1.56,  0.15,  0.  ,  0.18]),
#  array([ 0.21,  0.3 ,  1.33,  0.04]),
#  array([ 1.05,  0.54,  0.03,  0.26]),
#  array([ 1.37,  0.44,  0.  ,  0.08]),
#  array([ 0.92,  0.72,  0.  ,  0.24]),
#  array([ 0.25,  0.12,  1.48,  0.03]),
#  array([ 0.89,  0.69,  0.09,  0.21]),
#  array([ 1.42,  0.36,  0.03,  0.07]),
#  array([ 0.47,  0.08,  0.  ,  1.33]),
#  array([ 0.96,  0.53,  0.3 ,  0.09]),
#  array([ 0.22,  1.47,  0.04,  0.14]),
#  array([ 0.53,  0.16,  1.07,  0.1 ]),
#  array([ 0.73,  0.62,  0.4 ,  0.12]),
#  array([ 0.87,  0.52,  0.41,  0.06]),
#  array([ 1.75,  0.03,  0.  ,  0.08]),
#  array([ 1.12,  0.69,  0.03,  0.02]),
#  array([ 0.94,  0.44,  0.39,  0.1 ]),
#  array([ 1.37,  0.41,  0.04,  0.04]),
#  array([ 0.  ,  1.37,  0.  ,  0.49]),
#  array([ 0.64,  0.92,  0.01,  0.29]),
#  array([ 0.91,  0.71,  0.  ,  0.24]),
#  array([ 1.34,  0.37,  0.  ,  0.15]),
#  array([ 0.62,  0.42,  0.69,  0.12]),
#  array([ 0.85,  0.71,  0.13,  0.16]),
#  array([ 0.61,  0.59,  0.55,  0.11]),
#  array([ 1.33,  0.49,  0.  ,  0.03]),
#  array([ 0.83,  0.82,  0.  ,  0.2 ]),
#  array([ 1.26,  0.18,  0.35,  0.06]),
#  array([ 0.8 ,  0.19,  0.83,  0.03]),
#  array([ 1.05,  0.49,  0.08,  0.23]),
#  array([ 0.  ,  1.1 ,  0.42,  0.33]),
#  array([ 0.97,  0.34,  0.35,  0.18]),
#  array([ 1.53,  0.05,  0.  ,  0.25]),
#  array([ 0.83,  0.06,  0.93,  0.  ]),
#  array([ 1.31,  0.49,  0.  ,  0.03]),
#  array([ 0.84,  0.76,  0.  ,  0.23]),
#  array([ 1.33,  0.4 ,  0.03,  0.07]),
#  array([ 0.46,  1.02,  0.07,  0.28]),
#  array([ 0.25,  0.07,  1.49,  0.02]),
#  array([ 1.09,  0.54,  0.02,  0.17]),
#  array([ 0.92,  0.33,  0.52,  0.05]),
#  array([ 0.61,  0.34,  0.79,  0.09]),
#  array([ 1.24,  0.43,  0.03,  0.12]),
#  array([ 1.73,  0.07,  0.  ,  0.02]),
#  array([ 1.81,  0.  ,  0.  ,  0.  ]),
#  array([ 0.91,  0.74,  0.07,  0.09]),
#  array([ 0.22,  0.21,  1.35,  0.03]),
#  array([ 0.55,  0.84,  0.11,  0.31]),
#  array([ 1.05,  0.59,  0.  ,  0.18]),
#  array([ 1.1 ,  0.51,  0.12,  0.08]),
#  array([ 0.78,  0.44,  0.56,  0.04]),
#  array([ 0.88,  0.69,  0.  ,  0.23]),
#  array([ 1.  ,  0.03,  0.  ,  0.77]),
#  array([ 0.93,  0.59,  0.21,  0.07]),
#  array([ 1.66,  0.  ,  0.01,  0.13]),
#  array([ 1.41,  0.21,  0.03,  0.16]),
#  array([ 1.  ,  0.68,  0.  ,  0.12]),
#  array([ 0.49,  0.96,  0.07,  0.27]),
#  array([ 1.26,  0.39,  0.08,  0.06]),
#  array([ 0.52,  0.88,  0.06,  0.34]),
#  array([ 1.05,  0.57,  0.03,  0.14]),
#  array([ 1.25,  0.29,  0.  ,  0.24]),
#  array([ 0.23,  0.03,  1.49,  0.03]),
#  array([ 1.12,  0.58,  0.  ,  0.08]),
#  array([ 0.39,  1.01,  0.02,  0.36]),
#  array([ 0.32,  0.95,  0.36,  0.14]),
#  array([ 0.45,  0.94,  0.06,  0.33]),
#  array([ 0.41,  0.46,  0.72,  0.19]),
#  array([ 0.93,  0.57,  0.14,  0.13]),
#  array([ 0.85,  0.76,  0.  ,  0.16]),
#  array([ 1.16,  0.45,  0.  ,  0.16]),
#  array([ 0.31,  0.54,  0.84,  0.08]),
#  array([ 1.59,  0.03,  0.  ,  0.15]),
#  array([ 0.24,  0.09,  1.33,  0.12]),
#  array([ 0.63,  0.06,  1.03,  0.04]),
#  array([ 1.19,  0.29,  0.24,  0.06]),
#  array([ 1.07,  0.45,  0.01,  0.24]),
#  array([ 0.85,  0.31,  0.56,  0.04]),
#  array([ 1.27,  0.42,  0.  ,  0.07]),
#  array([ 1.06,  0.54,  0.  ,  0.16]),
#  array([ 0.93,  0.38,  0.4 ,  0.06]),
#  array([ 1.02,  0.47,  0.2 ,  0.07]),
#  array([ 0.53,  0.12,  1.09,  0.02]),
#  array([ 0.86,  0.67,  0.  ,  0.22]),
#  array([ 1.23,  0.46,  0.  ,  0.07]),
#  array([ 0.86,  0.67,  0.  ,  0.22]),
#  array([ 0.72,  0.69,  0.04,  0.31]),
#  array([ 0.68,  0.9 ,  0.01,  0.17]),
#  array([ 1.26,  0.47,  0.  ,  0.03]),
#  array([ 1.11,  0.48,  0.  ,  0.16]),
#  ...]

# %%
result.count()
# Out:
# 16598

# %%
datacluster = KMeans.train(result, 3, maxIterations=1000, initializationMode="random")

# %%
predictdata = result.map(datacluster.predict)
X = result.collect()
label = predictdata.collect()

# %%
import numpy as np
import matplotlib.pyplot as plt


for point in range(len(label)):
    if (label[point]==0):
        color = "r";
    elif (label[point]==1):
        color = "g";
    elif (label[point]==2):
        color = "b";
    lines = plt.plot(X[point][0], X[point][1] ,'ro')
    plt.setp(lines, color=color, linewidth=2.0)
    center =datacluster.clusterCenters
print center
for centroid in range(len(center)):
    lines = plt.plot(center[centroid][0],center[centroid][1],'bx')
    plt.setp(lines, color="y", markersize=10)
plt.show()
# Out:
# [array([ 2.21783537,  1.32657012,  0.42266768,  0.40405488]), array([ 0.16083265,  0.08569974,  0.05803808,  0.02944511]), array([ 13.05931034,   6.90206897,   3.11      ,   2.21137931])]
